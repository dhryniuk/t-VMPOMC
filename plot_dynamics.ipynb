# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif"
})

# %%
mag = np.genfromtxt("Ising_decay_chi1_N1_hx0.5_γd0/list_of_mag_chi1_N1_hx0.5_γd0.data",delimiter=",",unpack=True)
#print(mag)
#x=np.linspace(0,201)
plt.plot(mag[2], linewidth=1.0, label="SR")
