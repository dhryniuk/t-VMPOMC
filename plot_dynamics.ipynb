# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif"
})

# %%
plt.figure(dpi=2000)
mag = np.genfromtxt("Markovian_Ising_decay_chi1_N1_hx1.0_γd0/list_of_mag_chi1_N1_hx1.0_γd0.data",delimiter=",",unpack=True)
#print(mag)
#x=np.linspace(0,201)
plt.plot(mag[2], linewidth=1.0, label="Markov", color="blue")

magNM = np.genfromtxt("Ising_decay_chi1_N1_hx1.0_γd0/list_of_mag_chi1_N1_hx1.0_γd0.data",delimiter=",",unpack=True)
plt.plot(magNM[2], linewidth=1.0, label="NonMarkov", color="red")

mag_exact = np.genfromtxt("Markovian_mz_data.txt",delimiter=",",unpack=True)
plt.plot(np.arange(0,1000,1),mag_exact, linewidth=1.0, label="ExactMarkov", color="grey",linestyle="dashed")

magNM_exact = np.genfromtxt("mz_data.txt",delimiter=",",unpack=True)
plt.plot(np.arange(0,1000,1),magNM_exact, linewidth=1.0, label="ExactNonMarkov", color="grey",linestyle="dashed")

# %%
plt.figure(dpi=2000)
mag = np.genfromtxt("Markovian_Ising_decay_chi1_N1_hx0.5_γd0/list_of_mag_chi1_N1_hx0.5_γd0.data",delimiter=",",unpack=True)
#print(mag)
#x=np.linspace(0,201)
plt.plot(mag[2], linewidth=1.0, label="Markov", color="blue")

magNM = np.genfromtxt("Ising_decay_chi1_N1_hx0.5_γd0/list_of_mag_chi1_N1_hx0.5_γd0.data",delimiter=",",unpack=True)
plt.plot(magNM[2], linewidth=1.0, label="NonMarkov", color="red")
